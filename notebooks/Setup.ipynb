# %%
import os
import datajoint as dj
from spyglass.settings import SpyglassConfig

base_dir = "/media/labuser/NA_1_2025/spyglass/wilbur/"


# change to the root directory of the project
if os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")


# save the configuration
SpyglassConfig().save_dj_config(
    save_method="local",  # global or local
    base_dir= base_dir,
    database_user="anirudh",
    database_password="promptlyby12",
    database_host="172.16.102.154",  
    database_port=3306,
    set_password=False,
)

#connect to the database
dj.conn()

import spyglass.common as sgc
# dj.Diagram(sgc.AnalysisNwbfile) 
# -1 + 1
# sgc.AnalysisNwbfile().cleanup()
# Out:
# [11:41:05][WARNING] Spyglass: Failed to load SpyglassConfig. Please set up config file.
# [2026-04-16 11:41:07,793][INFO]: Saved settings in dj_local_conf.json
# [2026-04-16 11:41:07,807][INFO]: DataJoint 0.14.9 connected to anirudh@172.16.102.154:3306
